# %%
import pandas as pd

# %%
dataset = pd.read_csv("GlobalLandTemperaturesByCity.csv")
dataset
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 1        1743-12-01                 NaN                            NaN
# 2        1744-01-01                 NaN                            NaN
# 3        1744-02-01                 NaN                            NaN
# 4        1744-03-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 0         Århus      Denmark   57.05N    10.33E
# ...

# %%
a1 = ((1-(dataset.isnull().sum()/dataset.shape[0]))*100)
print(a1)
# PRINTS PERCENTAGE OF DATA THAT IS NOT NULL
# Out:
# dt                               100.000000
# AverageTemperature                95.765542
# AverageTemperatureUncertainty     95.765542
# City                             100.000000
# Country                          100.000000
# Latitude                         100.000000
# Longitude                        100.000000
# dtype: float64

# %%
a1.duplicated()
# Out:
# dt                               False
# AverageTemperature               False
# AverageTemperatureUncertainty     True
# City                              True
# Country                           True
# Latitude                          True
# Longitude                         True
# dtype: bool
