# %% [markdown]
#  <h1> Atharva Jagdale 20BCM007 </h1>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h1> MEAN </h1>
# <hr>

# %%
df = pd.read_csv('prac_2_data.csv')

# %%
df.shape
# Out:
# (510, 7)

# %%
df.isnull().sum()
# Out:
# CRIM       0
# INDUS      0
# RM       129
# AGE        0
# DIS        0
# TAX        0
# LSTAT      0
# dtype: int64

# %%
((df.isnull().sum())/df.shape[0])*100
# Out:
# CRIM      0.000000
# INDUS     0.000000
# RM       25.294118
# AGE       0.000000
# DIS       0.000000
# TAX       0.000000
# LSTAT     0.000000
# dtype: float64

# %%
df.iloc[:10,:]
# Out:
#       CRIM  INDUS     RM    AGE     DIS  TAX  LSTAT
# 0  0.00632   2.31  6.575   65.2  4.0900  296   4.98
# 1  0.02731   7.07  6.421   78.9  4.9671  242   9.14
# 2  0.02729   7.07  7.185   61.1  4.9671  242   4.03
# 3  0.03237   2.18  6.998   45.8  6.0622  222   2.94
# 4  0.06905   2.18  7.147   54.2  6.0622  222   5.33
# 5  0.02985   2.18    NaN   58.7  6.0622  222   5.21
# 6  0.08829   7.87  6.012   66.6  5.5605  311  12.43
# 7  0.14455   7.87    NaN   96.1  5.9505  311  19.15
# 8  0.21124   7.87  5.631  100.0  6.0821  311  29.93
# 9  0.17004   7.87  6.004   85.9  6.5921  311  17.10

# %%
df['RM'].mean()
# Out:
# 6.246658792650918

# %%
df['RM'] = df['RM'].fillna(df['RM'].mean())

# %%
df.iloc[0:10,:]
# Out:
#       CRIM  INDUS        RM    AGE     DIS  TAX  LSTAT
# 0  0.00632   2.31  6.575000   65.2  4.0900  296   4.98
# 1  0.02731   7.07  6.421000   78.9  4.9671  242   9.14
# 2  0.02729   7.07  7.185000   61.1  4.9671  242   4.03
# 3  0.03237   2.18  6.998000   45.8  6.0622  222   2.94
# 4  0.06905   2.18  7.147000   54.2  6.0622  222   5.33
# 5  0.02985   2.18  6.246659   58.7  6.0622  222   5.21
# 6  0.08829   7.87  6.012000   66.6  5.5605  311  12.43
# 7  0.14455   7.87  6.246659   96.1  5.9505  311  19.15
# 8  0.21124   7.87  5.631000  100.0  6.0821  311  29.93
# 9  0.17004   7.87  6.004000   85.9  6.5921  311  17.10

# %% [markdown]
# <h1> MODE (Most Frequency) </h1>
# <hr>

# %%
df2 = pd.read_csv('prac_2_data.csv')

# %%
dropped_df = df2.dropna(axis=0)

# %%
dropped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 381 entries, 0 to 509
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CRIM    381 non-null    float64
#  1   INDUS   381 non-null    float64
#  2   RM      381 non-null    float64
#  3   AGE     381 non-null    float64
#  4   DIS     381 non-null    float64
#  5   TAX     381 non-null    int64
#  6   LSTAT   381 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 23.8 KB

# %%
df3 = pd.read_csv('prac_2_data.csv')

# %%
df3['RM'].mode()
# Out:
# 0    6.98
# Name: RM, dtype: float64

# %%
df3['RM'] = df3['RM'].fillna(df3['RM'].mode()[0])

# %%
df3.iloc[:10,:]
# Out:
#       CRIM  INDUS     RM    AGE     DIS  TAX  LSTAT
# 0  0.00632   2.31  6.575   65.2  4.0900  296   4.98
# 1  0.02731   7.07  6.421   78.9  4.9671  242   9.14
# 2  0.02729   7.07  7.185   61.1  4.9671  242   4.03
# 3  0.03237   2.18  6.998   45.8  6.0622  222   2.94
# 4  0.06905   2.18  7.147   54.2  6.0622  222   5.33
# 5  0.02985   2.18  6.980   58.7  6.0622  222   5.21
# 6  0.08829   7.87  6.012   66.6  5.5605  311  12.43
# 7  0.14455   7.87  6.980   96.1  5.9505  311  19.15
# 8  0.21124   7.87  5.631  100.0  6.0821  311  29.93
# 9  0.17004   7.87  6.004   85.9  6.5921  311  17.10

# %% [markdown]
# <h1> Forward Fill </h1>
# <hr>

# %%
df4 = pd.read_csv('prac_2_data.csv')

# %%
df4['RM'].fillna(method='ffill',inplace=True)

# %%
df4.iloc[:10,:]
# Out:
#       CRIM  INDUS     RM    AGE     DIS  TAX  LSTAT
# 0  0.00632   2.31  6.575   65.2  4.0900  296   4.98
# 1  0.02731   7.07  6.421   78.9  4.9671  242   9.14
# 2  0.02729   7.07  7.185   61.1  4.9671  242   4.03
# 3  0.03237   2.18  6.998   45.8  6.0622  222   2.94
# 4  0.06905   2.18  7.147   54.2  6.0622  222   5.33
# 5  0.02985   2.18  7.147   58.7  6.0622  222   5.21
# 6  0.08829   7.87  6.012   66.6  5.5605  311  12.43
# 7  0.14455   7.87  6.012   96.1  5.9505  311  19.15
# 8  0.21124   7.87  5.631  100.0  6.0821  311  29.93
# 9  0.17004   7.87  6.004   85.9  6.5921  311  17.10

# %% [markdown]
# <h1> Backward Fill </h1>
# <hr>

# %%
df5 = pd.read_csv('prac_2_data.csv')

# %%
df5['RM'].fillna(method='bfill',inplace=True)

# %%
df5.iloc[:10,:]
# Out:
#       CRIM  INDUS     RM    AGE     DIS  TAX  LSTAT
# 0  0.00632   2.31  6.575   65.2  4.0900  296   4.98
# 1  0.02731   7.07  6.421   78.9  4.9671  242   9.14
# 2  0.02729   7.07  7.185   61.1  4.9671  242   4.03
# 3  0.03237   2.18  6.998   45.8  6.0622  222   2.94
# 4  0.06905   2.18  7.147   54.2  6.0622  222   5.33
# 5  0.02985   2.18  6.012   58.7  6.0622  222   5.21
# 6  0.08829   7.87  6.012   66.6  5.5605  311  12.43
# 7  0.14455   7.87  5.631   96.1  5.9505  311  19.15
# 8  0.21124   7.87  5.631  100.0  6.0821  311  29.93
# 9  0.17004   7.87  6.004   85.9  6.5921  311  17.10

# %% [markdown]
# <h1> Constant Value </h1>
# <hr>

# %%
df6 = pd.read_csv('prac_2_data.csv')

# %%
df6['RM'].fillna(0,inplace=True)

# %%
df6.iloc[:10,:]
# Out:
#       CRIM  INDUS     RM    AGE     DIS  TAX  LSTAT
# 0  0.00632   2.31  6.575   65.2  4.0900  296   4.98
# 1  0.02731   7.07  6.421   78.9  4.9671  242   9.14
# 2  0.02729   7.07  7.185   61.1  4.9671  242   4.03
# 3  0.03237   2.18  6.998   45.8  6.0622  222   2.94
# 4  0.06905   2.18  7.147   54.2  6.0622  222   5.33
# 5  0.02985   2.18  0.000   58.7  6.0622  222   5.21
# 6  0.08829   7.87  6.012   66.6  5.5605  311  12.43
# 7  0.14455   7.87  0.000   96.1  5.9505  311  19.15
# 8  0.21124   7.87  5.631  100.0  6.0821  311  29.93
# 9  0.17004   7.87  6.004   85.9  6.5921  311  17.10

# %% [markdown]
# <h1> Interpolation </h1>

# %%
df7 = pd.read_csv('prac_2_data.csv')

# %%
df7 = df7.interpolate(method="polynomial",order=2)

# %%
df7.iloc[:6,:]
# Out:
#       CRIM  INDUS        RM   AGE     DIS  TAX  LSTAT
# 0  0.00632   2.31  6.575000  65.2  4.0900  296   4.98
# 1  0.02731   7.07  6.421000  78.9  4.9671  242   9.14
# 2  0.02729   7.07  7.185000  61.1  4.9671  242   4.03
# 3  0.03237   2.18  6.998000  45.8  6.0622  222   2.94
# 4  0.06905   2.18  7.147000  54.2  6.0622  222   5.33
# 5  0.02985   2.18  6.702964  58.7  6.0622  222   5.21

# %%
df8 = pd.read_csv('prac_2_data.csv')

# %%
df8 = df8.interpolate(method="polynomial",order=3)

# %%
df8.iloc[:6,:]
# Out:
#       CRIM  INDUS        RM   AGE     DIS  TAX  LSTAT
# 0  0.00632   2.31  6.575000  65.2  4.0900  296   4.98
# 1  0.02731   7.07  6.421000  78.9  4.9671  242   9.14
# 2  0.02729   7.07  7.185000  61.1  4.9671  242   4.03
# 3  0.03237   2.18  6.998000  45.8  6.0622  222   2.94
# 4  0.06905   2.18  7.147000  54.2  6.0622  222   5.33
# 5  0.02985   2.18  6.740201  58.7  6.0622  222   5.21

# %%
df9 = pd.read_csv('prac_2_data.csv')

# %%
df9 = df9.interpolate(method="linear")

# %%
df9.iloc[:6,:]
# Out:
#       CRIM  INDUS      RM   AGE     DIS  TAX  LSTAT
# 0  0.00632   2.31  6.5750  65.2  4.0900  296   4.98
# 1  0.02731   7.07  6.4210  78.9  4.9671  242   9.14
# 2  0.02729   7.07  7.1850  61.1  4.9671  242   4.03
# 3  0.03237   2.18  6.9980  45.8  6.0622  222   2.94
# 4  0.06905   2.18  7.1470  54.2  6.0622  222   5.33
# 5  0.02985   2.18  6.5795  58.7  6.0622  222   5.21

# %% [markdown]
# <h1> Removing Rows with null values </h1>

# %%
df10 = pd.read_csv('prac_2_data.csv')

# %%
df10.dropna(inplace=True)

# %%
df10.iloc[:6,:]
# Out:
#       CRIM  INDUS     RM   AGE     DIS  TAX  LSTAT
# 0  0.00632   2.31  6.575  65.2  4.0900  296   4.98
# 1  0.02731   7.07  6.421  78.9  4.9671  242   9.14
# 2  0.02729   7.07  7.185  61.1  4.9671  242   4.03
# 3  0.03237   2.18  6.998  45.8  6.0622  222   2.94
# 4  0.06905   2.18  7.147  54.2  6.0622  222   5.33
# 6  0.08829   7.87  6.012  66.6  5.5605  311  12.43
