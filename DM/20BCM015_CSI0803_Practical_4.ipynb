# %% [markdown]
# <h2>APRIORI ALGORITHM</h2>
#     <h4>With Sample Data Set of Numbers</h4>

# %%
dataframe_list = [["1","3","4"],["2","3","5"],["1","2","3","5"],["2","5"],["1","2","3","5"]]
data = []
for i in range(0,len(dataframe_list)):
    a = [x for x in dataframe_list[i] if str(x) != 'nan']
    data.append([i,a])
print(data) 
print("Dataframe is ")
print(dataframe_list)

init = []
for i in data:
    for q in i[1]:
        if(q not in init):
            init.append(q)
init = sorted(init)
print(init)


s=2
# Out:
# [[0, ['1', '3', '4']], [1, ['2', '3', '5']], [2, ['1', '2', '3', '5']], [3, ['2', '5']], [4, ['1', '2', '3', '5']]]
# Dataframe is
# [['1', '3', '4'], ['2', '3', '5'], ['1', '2', '3', '5'], ['2', '5'], ['1', '2', '3', '5']]
# ['1', '2', '3', '4', '5']

# %%
#USER DEFINED FUNCTION FOR FINDING SUBSETS FOR PRUNING
import itertools
from itertools import combinations, chain
 
def findsubsets(s, n):
    return set(map(frozenset, itertools.combinations(s, n)))

# %%
from collections import Counter
c = Counter()
for i in init:
    for d in data:
        if(i in d[1]):
            c[i]+=1
print("C1:")
for i in c:
    print(str([i])+": "+str(c[i]))
print()
l = Counter()
for i in c:
    if(c[i] >= s):
        l[frozenset([i])]+=c[i]
print("L1:")
for i in l:
    print(str(list(i))+": "+str(l[i]))
print()
pl = l
pos = 1
for count in range (2,10):
    nc = set()
    temp = list(l)
    
    for i in range(0,len(temp)):
        for j in range(i+1,len(temp)):
            t = temp[i].union(temp[j])
           

            if(len(t) == count):
                nc.add(temp[i].union(temp[j]))
    
    nc = list(nc)
    pc = set()
    for i in nc:
        sub = findsubsets(i, count-1)
        sub=set(sub)
        if sub.issubset(set(temp)):
          pc.add(i)
    nc = list(pc)

    c = Counter()
    for i in nc:
        c[i] = 0
        for q in data:
            temp = set(q[1])
            if(i.issubset(temp)):
                c[i]+=1
    
    print("C"+str(count)+":")
    for i in c:
        print(str(list(i))+": "+str(c[i]))
    print()
   
    l = Counter()
    for i in c:
        if(c[i] >= s):
            l[i]+=c[i]
    print("L"+str(count)+":")
    for i in l:
        print(str(list(i))+": "+str(l[i]))
    print()
    
    
    if(len(l) == 0):
        break
    pl = l
    pos = count
print("Result: ")
print("L"+str(pos)+":")
for i in pl:
    print(str(list(i))+": "+str(pl[i]))
# Out:
# C1:
# ['1']: 3
# ['2']: 4
# ['3']: 4
# ['4']: 1
# ['5']: 4
#
# L1:
# ['1']: 3
# ['2']: 4
# ['3']: 4
# ['5']: 4
#
# C2:
# ['2', '3']: 3
# ['2', '1']: 2
# ['5', '3']: 3
# ['2', '5']: 4
# ['1', '3']: 3
# ['1', '5']: 2
#
# L2:
# ['2', '3']: 3
# ['2', '1']: 2
# ['5', '3']: 3
# ['2', '5']: 4
# ['1', '3']: 3
# ['1', '5']: 2
#
# C3:
# ['2', '5', '3']: 3
# ['2', '1', '3']: 2
# ['2', '1', '5']: 2
# ['1', '5', '3']: 2
#
# L3:
# ['2', '5', '3']: 3
# ['2', '1', '3']: 2
# ['2', '1', '5']: 2
# ['1', '5', '3']: 2
#
# C4:
# ['2', '1', '3', '5']: 2
#
# L4:
# ['2', '1', '3', '5']: 2
#
# C5:
#
# L5:
#
# Result:
# L4:
# ['2', '1', '3', '5']: 2

# %% [markdown]
# <h4>By:</h4>
# <h4>Devdeepsinh Zala<br><br>20BCM015<h4>
